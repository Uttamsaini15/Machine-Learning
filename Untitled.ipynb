# %%
import pandas as pd
import numpy as np
df2 = pd.DataFrame({'X':['B','B','A','A'], 'Y':[1,2,3,4]})
df2.groupby(['X']).agg([np.sum, np.mean, np.std])
# Out:
#     Y
#   sum mean       std
# X
# A   7  3.5  0.707107
# B   3  1.5  0.707107
